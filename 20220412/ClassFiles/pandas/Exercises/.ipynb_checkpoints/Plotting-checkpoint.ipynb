# %% [markdown]
# # Plotting

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline

import sqlite3
import numpy as np
import pandas as pd
#pd.options.display.mpl_style = 'default'
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10)

# %% [markdown]
# ## Create DataFrame from SQL Query

# %%
connection = sqlite3.connect('../lahman2014.sqlite')

query = '''SELECT CAST(strftime('%Y', debut / 1000, 'unixepoch') as decimal)  year, avg(weight) weight
FROM master
WHERE debut is NOT NULL
GROUP BY year
ORDER BY year'''

df = pd.read_sql_query(query, connection, coerce_float=True, index_col="year")

# %% [markdown]
# ## Create Plot

# %%
p=df.plot(title='Baseball: Player Weight Over the Years',
        style=['k'],
        figsize=(12,6),
        lw=3
       )

p.margins(x=0)

p.set_xlabel('Year',fontsize=20)
p.set_ylabel('Weight (lb.)',fontsize=20)
p.legend(['Weight'], loc="upper left",fontsize='xx-large')
p.grid(True)

p.annotate(s='Steroids Era Ends',
          xy=(2010,211),
          xytext=(1990,205),
          bbox=dict(boxstyle='round,pad=0.5',fc='white',alpha=1),
          arrowprops=dict(arrowstyle='->',connectionstyle='arc3,rad=-.2',color='black'),
          ha='right',
          va='bottom',
          fontsize=16
         )
# Out:
# Text(1990,205,'Steroids Era Ends')
